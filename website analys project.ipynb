# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data-export (1).csv")

# %%
df.head()
# Out:
#           # ----------------------------------------  \
# 0  Session primary channel group (Default channel...
# 1                                             Direct
# 2                                     Organic Social
# 3                                             Direct
# 4                                     Organic Social
#
#                  Unnamed: 1 Unnamed: 2 Unnamed: 3        Unnamed: 4  \
# 0  Date + hour (YYYYMMDDHH)      Users   Sessions  Engaged sessions
# 1                2024041623        237        300               144
# 2                2024041719        208        267               132
# 3                2024041723        188        233               115
# 4                2024041718        187        256               125
#
#                             Unnamed: 5                 Unnamed: 6  \
# 0  Average engagement time per session  Engaged sessions per user
# 1                   47.526666666666700         0.6075949367088610
# ...

# %%
import pandas as pd

# Read CSV, skipping the first row (because actual headers are on 2nd row)
df = pd.read_csv("data-export (1).csv", skiprows=1)

# Now assign your custom column names
df.columns = [
    "Channel Group",
    "Date (YYYYMMDDHH)",
    "Users",
    "Sessions",
    "Engaged Sessions",
    "Average engagement time per session",
    "Engaged sessions per user",
    "Events per session",
    "Event count",
    "Engagement rate"
]

# Reset index if needed
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#     Channel Group  Date (YYYYMMDDHH)  Users  Sessions  Engaged Sessions  \
# 0          Direct         2024041623    237       300               144
# 1  Organic Social         2024041719    208       267               132
# 2          Direct         2024041723    188       233               115
# 3  Organic Social         2024041718    187       256               125
# 4  Organic Social         2024041720    175       221               112
#
#    Average engagement time per session  Engaged sessions per user  \
# 0                            47.526667                   0.607595
# 1                            32.097378                   0.634615
# 2                            39.939914                   0.611702
# 3                            32.160156                   0.668449
# 4                            46.918552                   0.640000
#
#    Events per session  Event count  Engagement rate
# 0            4.673333     0.480000             1402
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3182 entries, 0 to 3181
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Channel Group                        3182 non-null   object
#  1   Date (YYYYMMDDHH)                    3182 non-null   int64
#  2   Users                                3182 non-null   int64
#  3   Sessions                             3182 non-null   int64
#  4   Engaged Sessions                     3182 non-null   int64
#  5   Average engagement time per session  3182 non-null   float64
#  6   Engaged sessions per user            3182 non-null   float64
#  7   Events per session                   3182 non-null   float64
#  8   Event count                          3182 non-null   float64
#  9   Engagement rate                      3182 non-null   int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 248.7+ KB

# %%
df["Date (YYYYMMDDHH)"] = pd.to_datetime(df["Date (YYYYMMDDHH)"], format = "%Y%m%d%H", errors= 'coerce')
df.head()
# Out:
#     Channel Group   Date (YYYYMMDDHH)  Users  Sessions  Engaged Sessions  \
# 0          Direct 2024-04-16 23:00:00    237       300               144
# 1  Organic Social 2024-04-17 19:00:00    208       267               132
# 2          Direct 2024-04-17 23:00:00    188       233               115
# 3  Organic Social 2024-04-17 18:00:00    187       256               125
# 4  Organic Social 2024-04-17 20:00:00    175       221               112
#
#    Average engagement time per session  Engaged sessions per user  \
# 0                            47.526667                   0.607595
# 1                            32.097378                   0.634615
# 2                            39.939914                   0.611702
# 3                            32.160156                   0.668449
# 4                            46.918552                   0.640000
#
#    Events per session  Event count  Engagement rate
# 0            4.673333     0.480000             1402
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3182 entries, 0 to 3181
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Channel Group                        3182 non-null   object
#  1   Date (YYYYMMDDHH)                    3182 non-null   datetime64[ns]
#  2   Users                                3182 non-null   int64
#  3   Sessions                             3182 non-null   int64
#  4   Engaged Sessions                     3182 non-null   int64
#  5   Average engagement time per session  3182 non-null   float64
#  6   Engaged sessions per user            3182 non-null   float64
#  7   Events per session                   3182 non-null   float64
#  8   Event count                          3182 non-null   float64
#  9   Engagement rate                      3182 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(4), object(1)
# ...

# %%
numeric_cols = df.columns.drop(["Channel Group", "Date (YYYYMMDDHH)"])
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors= 'coerce')
df["Hour"] = df["Date (YYYYMMDDHH)"].dt.hour

# %%
df.head()
# Out:
#     Channel Group   Date (YYYYMMDDHH)  Users  Sessions  Engaged Sessions  \
# 0          Direct 2024-04-16 23:00:00    237       300               144
# 1  Organic Social 2024-04-17 19:00:00    208       267               132
# 2          Direct 2024-04-17 23:00:00    188       233               115
# 3  Organic Social 2024-04-17 18:00:00    187       256               125
# 4  Organic Social 2024-04-17 20:00:00    175       221               112
#
#    Average engagement time per session  Engaged sessions per user  \
# 0                            47.526667                   0.607595
# 1                            32.097378                   0.634615
# 2                            39.939914                   0.611702
# 3                            32.160156                   0.668449
# 4                            46.918552                   0.640000
#
#    Events per session  Event count  Engagement rate  Hour
# 0            4.673333     0.480000             1402    23
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3182 entries, 0 to 3181
# Data columns (total 11 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Channel Group                        3182 non-null   object
#  1   Date (YYYYMMDDHH)                    3182 non-null   datetime64[ns]
#  2   Users                                3182 non-null   int64
#  3   Sessions                             3182 non-null   int64
#  4   Engaged Sessions                     3182 non-null   int64
#  5   Average engagement time per session  3182 non-null   float64
#  6   Engaged sessions per user            3182 non-null   float64
#  7   Events per session                   3182 non-null   float64
#  8   Event count                          3182 non-null   float64
#  9   Engagement rate                      3182 non-null   int64
#  10  Hour                                 3182 non-null   int32
# ...

# %%
df.describe()
# Out:
#                    Date (YYYYMMDDHH)        Users     Sessions  \
# count                           3182  3182.000000  3182.000000
# mean   2024-04-20 01:17:07.278441216    41.935889    51.192646
# min              2024-04-06 00:00:00     0.000000     1.000000
# 25%              2024-04-13 02:15:00    20.000000    24.000000
# 50%              2024-04-20 02:00:00    42.000000    51.000000
# 75%              2024-04-26 22:00:00    60.000000    71.000000
# max              2024-05-03 23:00:00   237.000000   300.000000
# std                              NaN    29.582258    36.919962
#
#        Engaged Sessions  Average engagement time per session  \
# count       3182.000000                          3182.000000
# mean          28.325581                            66.644581
# min            0.000000                             0.000000
# 25%           13.000000                            32.103034
# 50%           27.000000                            49.020202
# ...

# %% [markdown]
# # sessions and users overtime

# %%
sns.set(style="whitegrid")

# %%
plt.figure(figsize=(10,5))
df.groupby("Date (YYYYMMDDHH)")[["Sessions", "Users"]].sum().plot(ax=plt.gca())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # total users by channel

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df, x="Channel Group", y="Users", estimator=np.sum, palette="viridis")
plt.title("total users by channel")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Jyoti kumari\AppData\Local\Temp\ipykernel_21928\2215299169.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="Channel Group", y="Users", estimator=np.sum, palette="viridis")

# %% [markdown]
# # Average engagement time by channel

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df, x="Channel Group", y="Average engagement time per session", estimator=np.mean, palette="magma")
plt.title("Average engagement time by channel")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Jyoti kumari\AppData\Local\Temp\ipykernel_21928\3644504074.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="Channel Group", y="Average engagement time per session", estimator=np.mean, palette="magma")

# %% [markdown]
# # Enagagement rate distribution by channel

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x="Channel Group", y="Engagement rate", palette="magma")
plt.title("Engagement rate distrution by channel")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Jyoti kumari\AppData\Local\Temp\ipykernel_21928\88948435.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="Channel Group", y="Engagement rate", palette="magma")

# %% [markdown]
# # Engaged vs Non engaged sessions

# %%
df.head()
# Out:
#     Channel Group   Date (YYYYMMDDHH)  Users  Sessions  Engaged Sessions  \
# 0          Direct 2024-04-16 23:00:00    237       300               144
# 1  Organic Social 2024-04-17 19:00:00    208       267               132
# 2          Direct 2024-04-17 23:00:00    188       233               115
# 3  Organic Social 2024-04-17 18:00:00    187       256               125
# 4  Organic Social 2024-04-17 20:00:00    175       221               112
#
#    Average engagement time per session  Engaged sessions per user  \
# 0                            47.526667                   0.607595
# 1                            32.097378                   0.634615
# 2                            39.939914                   0.611702
# 3                            32.160156                   0.668449
# 4                            46.918552                   0.640000
#
#    Events per session  Event count  Engagement rate  Hour
# 0            4.673333     0.480000             1402    23
# ...

# %%
session_df = df.groupby("Channel Group")[["Sessions", "Engaged Sessions"]].sum().reset_index()
session_df["Non-Engaged"] = session_df["Sessions"] - session_df["Engaged Sessions"]
session_df_melted = session_df.melt(id_vars="Channel Group", value_vars=["Engaged Sessions", "Non-Engaged"])

plt.figure(figsize=(8,5))
sns.barplot(data=session_df_melted, x="Channel Group", y= "value", hue="variable")
plt.title(" Enagaged vs Non engaged sessions")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Traffic by hour and channel

# %%
heatmap_data = df.groupby(["Channel Group", "Hour"])["Sessions"].sum().unstack().fillna(0)

plt.figure(figsize=(12,6))
sns.heatmap(heatmap_data, cmap="YlGnBu", linewidths=0.5, annot=True, fmt='.0f')
plt.title("Traffic by hour and channel")
plt.xlabel("Channel Group")
plt.ylabel("Hour of the day")
plt.show()

# %% [markdown]
# # Enagagemnt rate vs sessions over time

# %%
df_plot = df.groupby("Date (YYYYMMDDHH)")[["Engagement rate", "Sessions"]].mean().reset_index()

plt.figure(figsize=(10,5))
plt.plot(df_plot["Date (YYYYMMDDHH)"], df_plot["Engagement rate"], label="Engagement rate", color="green")
plt.plot(df_plot["Date (YYYYMMDDHH)"], df_plot["Sessions"], label="Sessions", color="blue")
plt.title("Enagagement rate vs sessions over time")
plt.xlabel("Datehour")
plt.legend()
plt.grid(True)
plt.show()
